# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("综合设计").master("local[*]").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled",True) # 设置dataframe的显示格式

# %%
df = spark.read.option("inferSchema","true").option("header","true").csv("/data/data.csv") # 读取csv文件

# %%
df

# %%
df = df.drop("_c0")

# %%
df

# %% [markdown]
# ### 预处理

# %%
from pyspark.sql.functions import split,col,regexp_replace

# %%
df = df.withColumn("xiaoqu",split(col("address")," ")[0])

# %%
df

# %%
regex = "^\D\D+"

# %%
df = df.withColumn("BuildingTime",regexp_replace(col("BuildingTime"),regex,''))

# %%
df

# %%
df.write.format("csv").option("sep",',').option("header","true").save("/data/dataprocessed")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df.write.format("csv").option("sep",',').option("header","true").save("/data/dataprocessed")
#
# NameError: name 'df' is not defined

# %%
df = spark.read.option("inferSchema","true").option("header","true").csv("/data/dataprocessed") # 读取csv文件

# %%
df.select("BuildingArea","SubwayDistance","price_total","price_square","price_dy").describe()

# %%
df.select("BuildingArea","SubwayDistance","price_total","price_square","price_dy").summary()

# %% [markdown]
# ### 房价最大值、最小值、平均值、中位数

# %%
import plotly.express as px

# %%
from pyspark.sql.functions import min,max,mean,expr,desc

# %%
import pyecharts.options as opts
from pyecharts.charts import Bar, Line

# %%
df.select("BuildingArea","SubwayDistance","price_total","price_square","price_dy").toPandas().quantile()

# %%
result = df.select(min("price_total").alias("房屋总价最小值(万)"),max("price_total").alias("房屋总价最大值(万)")
          ,mean("price_total").alias("房屋总价平均值(万)"),expr("percentile(price_total, array(0.5))[0]").alias("房屋总价中位数(万)")
           ,min("price_square").alias("房屋单位面积价格最小值(元/m2)"),max("price_square").alias("房屋单位面积价格最大值(元/m2)")
          ,mean("price_square").alias("房屋单位面积价格平均值(元/m2)"),
          expr("percentile(price_square, array(0.5))[0]").alias("单位面积房屋价格中位数(元/m2)"))

# %%
result

# %%
result

result_dict = result.toPandas().to_dict()

# %%
keys = [key for key in result_dict.keys()]

# %%
values = [value[0] for value in result_dict.values()]

# %%
x = ["最小值","最大值","平均值","中位数"]

# %%
values

# %%
bar = Bar()
bar.add_xaxis(x)
bar.add_yaxis("二手房房屋总价(万)",values[:4])
bar.add_yaxis("二手房房屋单位面积价格(元/m2)",values[4:])
bar.render_notebook()

# %%
df.groupBy("xiaoqu").agg(min("price_total").alias("房屋总价最小值(万)"),max("price_total").alias("房屋总价最大值(万)")
          ,min("price_square").alias("房屋单位面积价格最小值(元/m2)"),max("price_square").alias("房屋单位面积价格最大值(元/m2)"),
          expr("percentile(price_total, array(0.5))[0]").alias("房屋总价中位数(万)"),
          expr("percentile(price_square, array(0.5))[0]").alias("单位面积房屋价格中位数(元/m2)"))

# %%
df.groupBy("xiaoqu").agg(expr("percentile(price_total, array(0.5))[0]").alias("每个小区房屋总价中位数(万)"),
                        expr("percentile(price_square, array(0.5))[0]").alias("每个小区单位面积房屋价格中位数(元/m2)"))

# %%
df.select(expr("percentile(price_total, array(0.5))[0]").alias("合肥市房屋总价中位数(万)"),
         expr("percentile(price_square, array(0.5))[0]").alias("合肥市房屋单位面积价格中位数(万/m2)"))

# %%
df.select("address","price_total","price_square","labels","xiaoqu").orderBy(desc("price_square")).limit(20) # 单位面积最高价格

# %%
df.select("address","price_total","price_square","labels").orderBy(desc("price_total")).limit(20) # 房屋总价的最高价格

# %%
df.orderBy("price_square").limit(20) # 单位面积最低价格

# %%
df.orderBy("price_total").limit(20) # 单位面积最低价格

# %%
pd_df = df.groupBy("xiaoqu").mean("price_square","price_total").orderBy(desc("avg(price_square)")).limit(20).toPandas()

# %%
df.groupBy("xiaoqu").mean("price_square","price_total").orderBy(desc("avg(price_square)")).limit(20)

# %%
pd_df

# %%
pd_df.to_dict('list')

# %%
x = pd_df_dict['xiaoqu']

# %%
y1 = pd_df_dict['avg(price_square)']
y2 = pd_df_dict['avg(price_total)']

# %%
bar = (Bar().add_xaxis(xaxis_data=x).add_yaxis(series_name="房屋总价",y_axis= y2,).extend_axis(yaxis=opts.AxisOpts(
        name="二手房房屋总价平均值",type_="value",axislabel_opts=opts.LabelOpts(formatter="{value} 元/m2"),))
    .set_global_opts(tooltip_opts=opts.TooltipOpts(is_show=True, trigger="axis", axis_pointer_type="cross"),
    xaxis_opts=opts.AxisOpts(type_="category",axispointer_opts=opts.AxisPointerOpts(is_show=True, type_="shadow"),
            axislabel_opts={"rotate":45}),yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(formatter="{value} 万")),))
line = (Line().add_xaxis(xaxis_data=x).add_yaxis(series_name="房屋单位面积价格",yaxis_index=1,y_axis=y1
                                                 ,label_opts=opts.LabelOpts(is_show=False),))
bar.overlap(line).render_notebook()

# %%
from pyspark.sql.window import Window
windowXiaoqu = Window.partitionBy("xiaoqu").orderBy(desc("price_square"))

# %%
from pyspark.sql.functions import dense_rank
df.withColumn("rk",dense_rank().over(windowXiaoqu)).where(col("rk")<=3)

# %%
import plotly.express as px

# %%
pd_df = df.toPandas()

# %%
fig = px.scatter(pd_df,x='xiaoqu',y='price_square',color='xiaoqu',size = 'price_total')
fig.show()

# %%
fig = px.box(pd_df,x='huxing',y='price_square',color='huxing')
fig.show()

# %%
df
# Out:
# +-----------------------------------+--------------------------------------+------+------------+--------------+---------+------------+--------------+-----------+------------+--------+--------------------+------------------+
# |                              title|                               address|huxing|BuildingArea|      Position|Direction|BuildingTime|SubwayDistance|price_total|price_square|price_dy|              labels|            xiaoqu|
# +-----------------------------------+--------------------------------------+------+------------+--------------+---------+------------+--------------+-----------+------------+--------+--------------------+------------------+
# |     富世广场 红星路42电梯房 146...|   富世广场 黄山大厦-宿州路与红星路...|1室2厅|          63|中层（共29层）|     北向|    2012年建|             2|        146|       23174|    null|       满二,优质教育|          富世广场|
# |相府花园 步行街相府花园,三室两厅...|         相府花园 市府广场-淮河路118号|3室1厅|          91| 高层（共7层）|     南向|    2000年建|             2|        195|       21381|       6|                满五|          相府花园|
# |   海伦国际 4.5米挑高精装修2室送...|   滨湖海伦堡 新省府-滨湖海伦堡锦绣...|2室1厅|          46|高层（共30层）|     南向|        null|             1|         45|        9782|    null|满两年,好房推荐,精装|        滨湖海伦堡|
# |西环中心广场北区 2室1厅,简装,诚售。|   西环中心广场 黄岳路口-潜山路与黄...|2室1厅|          84|中层（共27层）|     南向|    2005年建|             3|        185|       22023|    null|            优质教育|      西环中心广场|
# |       正南香格里拉花园3室2厅精装修|   香格里拉花园 临泉东路-临泉路合家...|3室2厅|          89|高层（共33层）|     南向|    2008年建|             3|        115|       12912|    null|       满五,优质教育|      香格里拉花园|
# |             正南长虹世纪荣廷3室2厅|   长虹世纪荣廷 瑶海工业园-铜陵北路...|3室2厅|          92|低层（共33层）|     南向|    2017年建|          null|        125|       13506|      14|       满二,优质教育|      长虹世纪荣廷|
# +-----------------------------------+--------------------------------------+------+------------+--------------+---------+------------+--------------+-----------+------------+--------+--------------------+------------------+
# only showing top 20 rows

# %%
pd_df = df.toPandas()
fig = px.pie(pd_df,values='BuildingArea',names='xiaoqu')
fig.update_traces(textposition='inside', 
                  textinfo='percent+label'
                 )
# Out:
# <div>                            <div id="69288117-c381-49fb-858d-e66a5132efbf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69288117-c381-49fb-858d-e66a5132efbf")) {                    Plotly.newPlot(                        "69288117-c381-49fb-858d-e66a5132efbf",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"xiaoqu=%{label}<br>BuildingArea=%{value}<extra></extra>","labels":["\u5bcc\u4e16\u5e7f\u573a","\u76f8\u5e9c\u82b1\u56ed","\u6ee8\u6e56\u6d77\u4f26\u5821","\u62db\u5546\u57ce\u5e02\u4e3b\u573a(\u516c\u5bd3)","\u7f8e\u83f1\u65b0\u6751","\u6587\u660c\u96c5\u5c45","\u6587\u4e00\u4e91\u6e56\u8f69","\u94a2\u94c1\u4e8c\u6751","\u58a8\u8377\u540d\u90b8","\u6052\u5927\u4e2d\u592e\u5e7f\u573a","\u6ee8\u6e56\u745e\u56ed","\u4fdd\u5229\u62c9\u83f2\u516c\u9986","\u534e\u6da6\u6606\u4ed1\u5fa1\u516c\u5bd3","\u878d\u521b\u957f\u6c5f\u58f9\u53f7","\u6ee8\u6e56\u54c1\u9601","\u4e49\u4ed3\u5df7\u5c0f\u533a","\u5b9d\u6e7e\u56fd\u9645\u516c\u5bd3","\u897f\u73af\u4e2d\u5fc3\u5e7f\u573a","\u9999\u683c\u91cc\u62c9\u82b1\u56ed","\u957f\u8679\u4e16\u7eaa\u8363\u5ef7","\u9999\u6c5f\u4e16\u7eaa\u540d\u57ce","\u57ce\u5efa\u7425\u73c0\u540d\u57ce","\u4e2d\u6d77\u57ce","\u91d1\u8f89\u4f18\u6b65\u5927\u9053","\u6052\u76db\u8c6a\u5ead","\u91d1\u8f89\u4f18\u6b65\u5927\u9053","\u78a7\u6842\u56ed\u00b7\u6b63\u8363\u60a6\u73ba","\u9f99\u6e56\u00b7\u9f99\u8a89\u57ce","\u6c34\u4e0a\u56ed\u5c0f\u533a","\u6822\u666f\u8f69","\u5b9d\u4e1a\u57ce\u5e02\u7eff\u82d1\u5317\u533a","\u6052\u6da6\u6cb3\u7554\u96c5\u5c45","\u6d77\u5c14\u5730\u4ea7\u667a\u6167\u516c\u9986","\u98ce\u666f\u82d1","\u91d1\u8f89\u4f18\u6b65\u5927\u9053","\
# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 pd_new_df = df.groupBy("BuildingTime").count().mean("price_square")
#
# File /usr/local/lib/python3.9/site-packages/pyspark/sql/dataframe.py:1988, in DataFrame.__getattr__(self, name)
#    1978 """Returns the :class:`Column` denoted by ``name``.
#    1979
#    1980 .. versionadded:: 1.3.0
#    (...)
#    1985 [Row(age=2), Row(age=5)]
#    1986 """
#    1987 if name not in self.columns:
# -> 1988     raise AttributeError(
#    1989         "'%s' object has no attribute '%s'" % (self.__class__.__name__, name)
#    1990     )
#    1991 jc = self._jdf.apply(name)
#    1992 return Column(jc)
#
# AttributeError: 'DataFrame' object has no attribute 'mean'

# %%
pd_new_df
# Out:
# +------------+------------------+
# |BuildingTime| avg(price_square)|
# +------------+------------------+
# |    2016年建|20899.720930232557|
# |    2003年建|          18254.25|
# |    1996年建|           10625.6|
# |    2014年建|20451.394366197183|
# |    1986年建|32177.666666666668|
# |    1999年建|21615.571428571428|
# |    2018年建|20286.983606557376|
# |    1979年建|           24050.0|
# |    2017年建|         21593.925|
# |    2013年建|21660.985074626864|
# |    2002年建|24425.727272727272|
# |    1994年建|14490.333333333334|
# |    1995年建|           24293.3|
# |    2015年建|18004.396226415094|
# |    2005年建|           18233.0|
# |        null|23531.298969072166|
# |    1985年建|28986.666666666668|
# |    1990年建|         17206.375|
# |    1997年建|32633.166666666668|
# |    2004年建|        17779.0625|
# +------------+------------------+
# only showing top 20 rows

# %%
fig = px.scatter(pd_df.sort_values(by="BuildingTime",ascending=False),x='BuildingTime',y='price_square',
                     color='xiaoqu',size='price_total'
                    )
fig.show()
# Out:
# <div>                            <div id="e69a8294-e111-4c6c-b775-00bfe94238d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e69a8294-e111-4c6c-b775-00bfe94238d5")) {                    Plotly.newPlot(                        "e69a8294-e111-4c6c-b775-00bfe94238d5",                        [{"hovertemplate":"xiaoqu=\u91d1\u8f89\u4f18\u6b65\u5927\u9053<br>BuildingTime=%{x}<br>price_square=%{y}<br>price_total=%{marker.size}<extra></extra>","legendgroup":"\u91d1\u8f89\u4f18\u6b65\u5927\u9053","marker":{"color":"#636efa","size":[235,235,138,135,126,122,138,133,133,126,155,155,122,138,158,158,133,109,109,150,109,150,150,118,150,109,118,150,150,150,109,158],"sizemode":"area","sizeref":8.875,"symbol":"circle"},"mode":"markers","name":"\u91d1\u8f89\u4f18\u6b65\u5927\u9053","showlegend":true,"x":["2023\u5e74\u5efa","2023\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2021\u5e74\u5efa","2021\u5e74\u5efa","2021\u5e74\u5efa","2021\u5e74\u5efa","2021\u5e74\u5efa","2021\u5e74\u5efa","2021\u5e74\u5efa","2021\u5e74\u5efa","2021\u5e74\u5efa","2021\u5e74\u5efa","2021\u5e74\u5efa","2021\u5e74\u5efa","2021\u5e74\u5efa","2021\u5e74\u5efa","2020\u5e74\u5efa"],"xaxis":"x","y":[19883,19883,13341,13636,14157,13832,13341,14927,14927,14157,15656,15656,13832,13341,16043,16043,14927,12386,12386,15151,12386,15151,15151,13461,15151,12386,13461,15151,15151,15151,12386,15866],"yaxis":"y","type":"scattergl"},{"hovertemplate":"xiaoqu=\u658c\u950b\u5f53\u4ee3\u5e9cMOM\u039b<br>BuildingTime=%{x}<br>price_square=%{y}<br>price_total=%{marker.size}<extra></extra>","legendgroup":"\u658c\u950b\u5f53\u4ee3\u5e9cMOM\u039b","marker":{"color":"#EF553B","size":[116],"sizemode":"area","sizeref":8.875,"symbol":"circle"},"mode":"markers","name":"\u658c\u950b\u5f53\u4ee3\u5e9cMOM\u039b","showlegend":true,"x":["2022\u5e74\u5efa"],"xaxis":"x","y":[13033],"yaxis":"y","type":"scattergl"},{"hovertemplate":"xiaoqu=\u62db\u5546\u57ce\u5e02\u4e3b\u573a(\u516c\u5bd3)<br>BuildingTime=%{x}<br>price_square=%{y}<br>price_total=%{marker.size}<extra></extra>","legendgroup":"\u62db\u5546\u57ce\u5e02\u4e3b\u573a(\u516c\u5bd3)","marker":{"color":"#00cc96","size":[56],"sizemode":"area","sizeref":8.875,"symbol":"circle"},"mode":"markers","name":"\u62db\u5546\u57ce\u5e02\u4e3b\u573a(\u516c\u5bd3)","showlegend":true,"x":["2022\u5e74\u5efa"],"xaxis":"x","y":[10181],"yaxis":"y","type":"scattergl"},{"hovertemplate":"xiaoqu=\u4e3d\u4e30\u749e\u7fbd\u5c71<br>BuildingTime=%{x}<br>price_square=%{y}<br>price_total=%{marker.size}<extra></extra>","legendgroup":"\u4e3d\u4e30\u749e\u7fbd\u5c71","marker":{"color":"#ab63fa","size":[257,400,305,400,257],"sizemode":"area","sizeref":8.875,"symbol":"circle"},"mode":"markers","name":"\u4e3d\u4e30\u749e\u7fbd\u5c71","showlegend":true,"x":["2021\u5e74\u5efa","2021\u5e74\u5efa","2021\u5e74\u5efa","2021\u5e74\u5efa","2021\u5e74\u5efa"],"xaxis":"x","y":[24529,25173,25206,25173,24529],"yaxis":"y","type":"scattergl"},{"hovertemplate":"xiaoqu=\u4e2d\u6d77\u4e5d\u6a3e<br>BuildingTime=%{x}<br>price_square=%{y}<br>price_total=%{marker.size}<extra></extra>","legendgroup":"\u4e2d\u6d77\u4e5d\u6a3e","marker":{"color":"#FFA15A","size":[310,310,400],"sizemode":"area","sizeref":8.875,"symbol":"circle"},"mode":"markers","name":"\u4e2d\u6d77\u4e5d\u6a3e","showlegend":true,"x":["2021\u5e74\u5efa","2021\u5e74\u5efa","2014\u5e74\u5efa"],"xaxis":"x","y":[26497,26497,28776],"yaxis":"y","type":"scattergl"},{"hovertemplate":"xiaoqu=\u91d1\u9e4f\u00b7\u58f9\u54c1\u5929\u6210<br>BuildingTime=%{x}<br>price_square= ...

# %%
fig = px.violin(pd_df.sort_values(by="BuildingTime",ascending=False),x='BuildingTime',y='price_square',
                     color='BuildingTime',box=True
                    )
fig.show()
# Out:
# <div>                            <div id="e4bed885-0599-49fb-9217-62bb400930a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4bed885-0599-49fb-9217-62bb400930a3")) {                    Plotly.newPlot(                        "e4bed885-0599-49fb-9217-62bb400930a3",                        [{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"BuildingTime=%{x}<br>price_square=%{y}<extra></extra>","legendgroup":"2023\u5e74\u5efa","marker":{"color":"#636efa"},"name":"2023\u5e74\u5efa","offsetgroup":"2023\u5e74\u5efa","orientation":"v","scalegroup":"True","showlegend":true,"x":["2023\u5e74\u5efa","2023\u5e74\u5efa"],"x0":" ","xaxis":"x","y":[19883,19883],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"BuildingTime=%{x}<br>price_square=%{y}<extra></extra>","legendgroup":"2022\u5e74\u5efa","marker":{"color":"#EF553B"},"name":"2022\u5e74\u5efa","offsetgroup":"2022\u5e74\u5efa","orientation":"v","scalegroup":"True","showlegend":true,"x":["2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5efa","2022\u5e74\u5ef